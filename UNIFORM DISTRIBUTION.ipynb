# %% [markdown]
# ## Uniform Distribution

# %% [markdown]
# ## Generate 2*2 uniform distribution

# %%
from numpy import random

# %%
x = random.uniform(size =(2,3))

# %%
print(x)
# Out:
# [[0.46969483 0.21114443 0.39660364]
#  [0.40924593 0.39015415 0.08297542]]

# %% [markdown]
# ## VISUALIZATION OF UNIFORM DISTRIBUTION

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
uniform_data =random.uniform(size =1000)
sns.kdeplot(uniform_data,label='uniform',color ='brown')
# Out:
# <Axes: ylabel='Density'>
