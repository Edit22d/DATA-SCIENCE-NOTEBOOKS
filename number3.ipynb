# %% [markdown]
# ## Linear plotting

# %%
x = [1,2,3,4]
y1 = [1,4,2,3]
y2 = [2,3,4,5]

# %%
from numpy import random
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x_normal= random.normal([1,4,2,3])
sns.kdeplot(x_normal,label = 'Line 1',color = 'blue')
x_normal =random.normal([2,3,4,5])
sns.kdeplot(x_normal,label ='Line 2',color = 'red')
plt.legend()
plt.title('Multiple lines')
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# ## c (scatter plot)

# %%
import pandas as pd

# %%
adult_df

# %%
missing_null = adult_df('education-num').isnull()
